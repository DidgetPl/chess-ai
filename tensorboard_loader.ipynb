# %%
# !py -3.12 -m pip install tensorboard
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ensorflow (D:\Users\rober\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (D:\Users\rober\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (D:\Users\rober\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
# !D:\Users\rober\AppData\Local\Programs\Python\Python312\Scripts\tensorboard.exe --logdir logs
# Out:
# ^C
